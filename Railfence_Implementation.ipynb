# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvan0642/DBS_LAB_Record/blob/main/Railfence_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
def main():
    print("\n\t\t RAIL FENCE TECHNIQUE")
    a = input("\n\nEnter the input string : ")
    l = len(a)
    # Ciphering
    c = ''.join([a[i] for i in range(l) if i % 2 == 0])
    c += ''.join([a[i] for i in range(l) if i % 2 == 1])
    print("\nCipher text after applying rail fence :")
    print(c)
    # Deciphering
    k = l // 2 if l % 2 == 0 else (l // 2) + 1
    d = [''] * l
    for i in range(k):
        d[i*2] = c[i]
    for i in range(k, l):
        d[(i-k)*2 + 1] = c[i]
    d = ''.join(d)
    print("\nText after decryption : ")
    print(d)
    input("Press Enter to continue...")
if __name__ == "__main__":
    main()
# Out:
# 		 RAIL FENCE TECHNIQUE
#
#
# Enter the input string : i am sarvan
#
# Cipher text after applying rail fence :
# ia avn msra
#
# Text after decryption :
# i am sarvan
# Press Enter to continue...
