# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvan0642/DBS_LAB_Record/blob/main/RSA_RIVEST_SHAMIR_ALMIR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

def gcd(a, b):
    while b:
        a, b = b, a % b
    return a

print("Enter two prime numbers:")
p = int(input("p = "))
q = int(input("q = "))

n = p * q
phi = (p - 1) * (q - 1)

# Choose e
for e in range(2, phi):
    if gcd(e, phi) == 1:
        break

# Find d
for d in range(2, phi):
    if (d * e) % phi == 1:
        break

print("\nPublic Key (e, n):", (e, n))
print("Private Key (d, n):", (d, n))

msg = input("\nEnter message to encrypt: ")

# Encrypt
encrypted = [(ord(char) ** e) % n for char in msg]
print("Encrypted:", encrypted)

# Decrypt
decrypted = ''.join(chr((c ** d) % n) for c in encrypted)
print("Decrypted:", decrypted)
# Out:
# Enter two prime numbers:
# p = 3
# q = 5
#
# Public Key (e, n): (3, 15)
# Private Key (d, n): (3, 15)
#
# Enter message to encrypt: hello
# Encrypted: [14, 11, 12, 12, 6]
# Decrypted:
