# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvan0642/DBS_LAB_Record/blob/main/DES_Data_Encryption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from Crypto.Cipher import DES
from Crypto.Util.Padding import pad, unpad

# Key must be 8 bytes
key = b'12345678'

# Message
plain_text = input("Enter message: ").encode()

# Encrypt
cipher = DES.new(key, DES.MODE_ECB)
encrypted = cipher.encrypt(pad(plain_text, DES.block_size))
print("Encrypted (hex):", encrypted.hex())

# Decrypt
cipher = DES.new(key, DES.MODE_ECB)
decrypted = unpad(cipher.decrypt(encrypted), DES.block_size)
print("Decrypted:", decrypted.decode())
# Out:
# Enter message: hello
# Encrypted (hex): ba16c6a0257125af
# Decrypted: hello
